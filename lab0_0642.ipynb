# %%
# Writing data to a file

file = open("student.txt", "w")

file.write("Name: Neha\n")
file.write("Roll Number: 205\n")
file.write("Marks: 89\n")

file.close()

print("Data written successfully.")
# Out:
# Data written successfully.

# %%
# Reading data from a file

file = open("student.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Name: Neha
# Roll Number: 205
# Marks: 89

# %%
# Writing to a file

with open("student.txt", "w") as file:
    file.write("Name: Simran\n")
    file.write("Marks: 89\n")

# Reading from the file

with open("student.txt", "r") as file:
    data = file.read()

print(data)

with open("student.txt", "a") as file:
    file.write("Grade: A+\n")

print("New data added.")
with open("student.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# Name: Simran
# Marks: 89
#
# New data added.
# Name: Simran
# Marks: 89
# Grade: A+

# %%
# Pandas is a Python library mainly used for working with tabular data
# such as Excel sheets, CSV files, and database-like tables.
import pandas as pd

# Creating data
data = {
    "Name": ["Karan", "Mehak", "Arjun", "Simran"],
    "Age": [21, 20, 22, 19],
    "Marks": [90, 84, 95, 87]
}

# Creating DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Age  Marks
# 0   Karan   21     90
# 1   Mehak   20     84
# 2   Arjun   22     95
# 3  Simran   19     87

# %%
print(df[["Name", "Marks"]])
# Out:
#      Name  Marks
# 0   Karan     90
# 1   Mehak     84
# 2   Arjun     95
# 3  Simran     87

# %%
average = df["Marks"].mean()

print("Average Marks:", average)
# Out:
# Average Marks: 89.0

# %%
print("Highest Marks:", df["Marks"].max())
# Out:
# Highest Marks: 95

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df)
# Out:
#    Enrollment No.    Name
# 0               1   Karan
# 1               2   Mehak
# 2               3   Arjun
# 3               4  Simran

# %%
# NumPy stands for Numerical Python.
# It is mainly used for fast mathematical and numerical operations on arrays.
import numpy as np

numbers = np.array([15, 25, 35, 45, 55])

print(numbers)
# Out:
# [15 25 35 45 55]

# %%
import numpy as np

numbers = np.array([15, 25, 35, 45, 55])

print("Addition:", numbers + 5)
print("Subtraction:", numbers - 5)
print("Multiplication:", numbers * 2)
print("Division:", numbers / 2)
# Out:
# Addition: [20 30 40 50 60]
# Subtraction: [10 20 30 40 50]
# Multiplication: [ 30  50  70  90 110]
# Division: [ 7.5 12.5 17.5 22.5 27.5]

# %%
numbers * 2
# Out:
# array([ 30,  50,  70,  90, 110])

# %%
# Matplotlib is used to create graphs and charts in Python.
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [70, 76, 82, 88, 94]

plt.plot(tests, marks)

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [70, 76, 82, 88, 94]

plt.plot(tests, marks, marker="o")

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

students = ["Karan", "Mehak", "Arjun", "Simran"]
marks = [90, 84, 95, 87]

plt.bar(students, marks)

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

languages = ["Python", "Java", "C++", "C"]
students = [40, 30, 20, 10]

plt.pie(students, labels=languages, autopct="%1.1f%%")

plt.title("Programming Language Preference")

plt.show()

# %%
import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5, 6]
marks = [45, 50, 60, 68, 78, 90]

plt.scatter(study_hours, marks)

plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()
